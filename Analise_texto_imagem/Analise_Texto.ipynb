# %% [markdown]
# # Introdução Análise de Texto

# %% [markdown]
# ## Módulos

# %% [markdown]
# - Instalações

# %%
! sudo pip install unidecode
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.3.2-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 8.3 MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.2

# %% [markdown]
# - Carregamento

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from PIL import Image

# %%
import re
from unicodedata import normalize
import unidecode
import string

# %%
from spacy.lang.pt.stop_words import STOP_WORDS

# %% [markdown]
# ## Carregar dados

# %%
dados_cptm = pd.read_csv('dados_cptm.csv', encoding = 'latin1')

# %%
dados_cptm
# Out:
#                    created                  id  ... polaridade data_ajustada
# 0     2017-02-28T18:20:24Z  836687521182547968  ...         -1    2017-02-28
# 1     2017-02-28T18:20:13Z  836687476483731456  ...         -1    2017-02-28
# 2     2017-02-28T18:20:13Z  836687475984613376  ...          1    2017-02-28
# 3     2017-02-28T18:20:13Z  836687475468713984  ...         -1    2017-02-28
# 4     2017-02-28T18:09:15Z  836684713209257984  ...         -1    2017-02-28
# ...                    ...                 ...  ...        ...           ...
# 8465  2017-02-17T09:59:28Z  832575188168372224  ...          1    2017-02-17
# 8466  2017-02-17T09:59:27Z  832575187589615616  ...         -1    2017-02-17
# 8467  2017-02-17T09:39:26Z  832570147516747776  ...          1    2017-02-17
# 8468  2017-02-17T09:32:42Z  832568453659840513  ...          0    2017-02-17
# 8469  2017-02-17T08:39:25Z  832555045761585152  ...          1    2017-02-17
#
# [8470 rows x 6 columns]

# %%
dados_cptm.dtypes
# Out:
# created             object
# id                   int64
# texto_do_twitter    object
# screenName          object
# polaridade           int64
# data_ajustada       object
# dtype: object

# %% [markdown]
# ## Pré-processamento

# %% [markdown]
# ### Funções importantes

# %%
# retirar url's
url_re = re.compile('https?://(www.)?\w+\.\w+(/\w+)*/?')

# %%
# pontuacao
punc_re = re.compile('[%s]' % re.escape(string.punctuation))

# %%
# numeros
num_re = re.compile('(\\d+)')

# %%
# alfa numericos
alpha_num_re = re.compile("^[a-z0-9_.]+$")

# %%
# mencoes
mention_re = re.compile('@(\w+)')

# %% [markdown]
# ### Ajustes

# %% [markdown]
# - Deixar minúsculo

# %%
texto_ajustado = dados_cptm['texto_do_twitter'].apply(lambda x: x.lower())
texto_ajustado
# Out:
# 0       @cptm_oficial 20 min q estou esperando um trem...
# 1       [18h20] cptm: linha 11 - coral: velocidade red...
# 2       [18h20] cptm: linha 9 - esmeralda: operação no...
# 3       [18h20] cptm: linha 7 - rubi: velocidade reduz...
# 4       @_lcoliveira2016 @usuariosmetrosp @cptm_oficia...
#                               ...
# 8465    [10h59] cptm: linha 9 - esmeralda: operação no...
# 8466    [10h59] cptm: linha 7 - rubi: velocidade reduz...
# 8467    [10h39] cptm: linha 11 - coral: operação norma...
# 8468    ao embarcar ou desembarcar na cptm tenha muito...
# 8469    [09h39] cptm: linha 9 - esmeralda: operação no...
# Name: texto_do_twitter, Length: 8470, dtype: object

# %% [markdown]
# - Limpar url's

# %%
texto_ajustado[texto_ajustado.str.contains('http')]
# Out:
# 9       18h - obras alteram circulação dos trens duran...
# 10      18h - obras alteram circulação dos trens duran...
# 11      18h - obras alteram circulação dos trens duran...
# 12      18h - obras alteram circulação dos trens duran...
# 13      18h - obras alteram circulação dos trens duran...
#                               ...
# 8447    problemas nas linhas de trens e metro. saiba c...
# 8454    rt @cptm_oficial: #dicacultural olhares sobre ...
# 8457    #dicacultural olhares sobre os trilhos\n\n#vej...
# 8463    vontadinha de bater cabelo na cptm https://t.c...
# 8468    ao embarcar ou desembarcar na cptm tenha muito...
# Name: texto_do_twitter, Length: 2781, dtype: object

# %%
texto_ajustado[texto_ajustado.str.contains('http')].apply(lambda x: url_re.sub(' ', x))
# Out:
# 9       18h - obras alteram circulação dos trens duran...
# 10      18h - obras alteram circulação dos trens duran...
# 11      18h - obras alteram circulação dos trens duran...
# 12      18h - obras alteram circulação dos trens duran...
# 13      18h - obras alteram circulação dos trens duran...
#                               ...
# 8447    problemas nas linhas de trens e metro. saiba c...
# 8454    rt @cptm_oficial: #dicacultural olhares sobre ...
# 8457    #dicacultural olhares sobre os trilhos\n\n#vej...
# 8463                 vontadinha de bater cabelo na cptm
# 8468    ao embarcar ou desembarcar na cptm tenha muito...
# Name: texto_do_twitter, Length: 2781, dtype: object

# %%
texto_ajustado = texto_ajustado.apply(lambda x: url_re.sub(' ', x))

# %% [markdown]
# - Ajustar menções com @

# %%
texto_ajustado = texto_ajustado.apply(lambda x: mention_re.sub(' ', x))
texto_ajustado
# Out:
# 0         20 min q estou esperando um trem pra luz na ...
# 1       [18h20] cptm: linha 11 - coral: velocidade red...
# 2       [18h20] cptm: linha 9 - esmeralda: operação no...
# 3       [18h20] cptm: linha 7 - rubi: velocidade reduz...
# 4             durante a semana eles ñ reprimem o comér...
#                               ...
# 8465    [10h59] cptm: linha 9 - esmeralda: operação no...
# 8466    [10h59] cptm: linha 7 - rubi: velocidade reduz...
# 8467    [10h39] cptm: linha 11 - coral: operação norma...
# 8468    ao embarcar ou desembarcar na cptm tenha muito...
# 8469    [09h39] cptm: linha 9 - esmeralda: operação no...
# Name: texto_do_twitter, Length: 8470, dtype: object

# %% [markdown]
# - Ajustar pontuações (*punctuations marks*)

# %%
texto_ajustado = texto_ajustado.apply(lambda x: punc_re.sub(' ', x))
texto_ajustado
# Out:
# 0         20 min q estou esperando um trem pra luz na ...
# 1        18h20  cptm  linha 11   coral  velocidade red...
# 2        18h20  cptm  linha 9   esmeralda  operação no...
# 3        18h20  cptm  linha 7   rubi  velocidade reduz...
# 4             durante a semana eles ñ reprimem o comér...
#                               ...
# 8465     10h59  cptm  linha 9   esmeralda  operação no...
# 8466     10h59  cptm  linha 7   rubi  velocidade reduz...
# 8467     10h39  cptm  linha 11   coral  operação norma...
# 8468    ao embarcar ou desembarcar na cptm tenha muito...
# 8469     09h39  cptm  linha 9   esmeralda  operação no...
# Name: texto_do_twitter, Length: 8470, dtype: object

# %% [markdown]
# - Limpar numeração

# %%
texto_ajustado = texto_ajustado.apply(lambda x: num_re.sub(' ', x))
texto_ajustado
# Out:
# 0           min q estou esperando um trem pra luz na b...
# 1         h   cptm  linha     coral  velocidade reduzi...
# 2         h   cptm  linha     esmeralda  operação norm...
# 3         h   cptm  linha     rubi  velocidade reduzid...
# 4             durante a semana eles ñ reprimem o comér...
#                               ...
# 8465      h   cptm  linha     esmeralda  operação norm...
# 8466      h   cptm  linha     rubi  velocidade reduzid...
# 8467      h   cptm  linha     coral  operação normal  ...
# 8468    ao embarcar ou desembarcar na cptm tenha muito...
# 8469      h   cptm  linha     esmeralda  operação norm...
# Name: texto_do_twitter, Length: 8470, dtype: object

# %% [markdown]
# - Ajustar acentos

# %%
texto_ajustado = texto_ajustado.apply(lambda x: normalize('NFKD', x).encode('ASCII', 'ignore').decode('ASCII'))
texto_ajustado
# Out:
# 0           min q estou esperando um trem pra luz na b...
# 1         h   cptm  linha     coral  velocidade reduzi...
# 2         h   cptm  linha     esmeralda  operacao norm...
# 3         h   cptm  linha     rubi  velocidade reduzid...
# 4             durante a semana eles n reprimem o comer...
#                               ...
# 8465      h   cptm  linha     esmeralda  operacao norm...
# 8466      h   cptm  linha     rubi  velocidade reduzid...
# 8467      h   cptm  linha     coral  operacao normal  ...
# 8468    ao embarcar ou desembarcar na cptm tenha muito...
# 8469      h   cptm  linha     esmeralda  operacao norm...
# Name: texto_do_twitter, Length: 8470, dtype: object

# %% [markdown]
# - Limpar textos alfa numericos e palavras menores que 3 caracteres

# %%
def preprocessamento_texto(texto, n):
  '''Ajustar caracteres alfa numéricos e palavras menores que n
     texto: texto a ser ajustado
     n: tamanho mínimo das palavras'''
  list_pos = 0
  cleaned_str = ''
  for word in texto.split():
      if list_pos == 0:
          if alpha_num_re.match(word) and len(word) > n:
              cleaned_str = word
          else:
              cleaned_str = ' '
      else:
          if alpha_num_re.match(word) and len(word) > n:
              cleaned_str = cleaned_str + ' ' + word
          else:
              cleaned_str += ' '
      list_pos += 1
  return cleaned_str

# %%
texto_ajustado = texto_ajustado.apply(lambda x: preprocessamento_texto(x, 3))
texto_ajustado
# Out:
# 0                estou esperando  trem      nada  absurdo
# 1         cptm linha coral velocidade reduzida linha s...
# 2         cptm linha esmeralda operacao normal linha t...
# 3         cptm linha rubi velocidade reduzida linha di...
# 4       durante  semana eles  reprimem  comercio irreg...
#                               ...
# 8465      cptm linha esmeralda operacao normal linha t...
# 8466      cptm linha rubi velocidade reduzida linha di...
# 8467      cptm linha coral operacao normal linha safir...
# 8468      embarcar  desembarcar  cptm tenha muito cuid...
# 8469      cptm linha esmeralda operacao normal linha t...
# Name: texto_do_twitter, Length: 8470, dtype: object

# %% [markdown]
# - Ajustar palavras muito usadas (*stopwords*)

# %%
def remove_stops(texto):
    # expects a string
    stops = set(STOP_WORDS)
    list_pos = 0
    cleaned_str = ''
    text = texto.split()
    for word in text:
        if word not in stops:
            # rebuild cleaned_str
            if list_pos == 0:
                cleaned_str = word
            else:
                cleaned_str = cleaned_str + ' ' + word
            list_pos += 1
    return cleaned_str

# %%
list(STOP_WORDS)[0:15]
# Out:
# ['vem',
#  'nove',
#  'tentaram',
#  'foste',
#  'fostes',
#  'fora',
#  'seu',
#  'números',
#  'algumas',
#  'seus',
#  'oitava',
#  'oito',
#  'nem',
#  'lhe',
#  'sistema']

# %%
#STOP_WORDS.update({'cptm'})

# %%
texto_ajustado = texto_ajustado.apply(lambda x: remove_stops(x))
texto_ajustado
# Out:
# 0                                  esperando trem absurdo
# 1       cptm linha coral velocidade reduzida linha saf...
# 2       cptm linha esmeralda operacao normal linha tur...
# 3       cptm linha rubi velocidade reduzida linha diam...
# 4       durante semana reprimem comercio irregular que...
#                               ...
# 8465    cptm linha esmeralda operacao normal linha tur...
# 8466    cptm linha rubi velocidade reduzida linha diam...
# 8467    cptm linha coral operacao normal linha safira ...
# 8468    embarcar desembarcar cptm tenha cuidado altura...
# 8469    cptm linha esmeralda operacao normal linha tur...
# Name: texto_do_twitter, Length: 8470, dtype: object

# %% [markdown]
# - Gravar as mudanças no dataframe

# %%
dados_cptm['texto_twitter_ajustado'] = texto_ajustado

# %%
dados_cptm
# Out:
#                    created  ...                             texto_twitter_ajustado
# 0     2017-02-28T18:20:24Z  ...                             esperando trem absurdo
# 1     2017-02-28T18:20:13Z  ...  cptm linha coral velocidade reduzida linha saf...
# 2     2017-02-28T18:20:13Z  ...  cptm linha esmeralda operacao normal linha tur...
# 3     2017-02-28T18:20:13Z  ...  cptm linha rubi velocidade reduzida linha diam...
# 4     2017-02-28T18:09:15Z  ...  durante semana reprimem comercio irregular que...
# ...                    ...  ...                                                ...
# 8465  2017-02-17T09:59:28Z  ...  cptm linha esmeralda operacao normal linha tur...
# 8466  2017-02-17T09:59:27Z  ...  cptm linha rubi velocidade reduzida linha diam...
# 8467  2017-02-17T09:39:26Z  ...  cptm linha coral operacao normal linha safira ...
# 8468  2017-02-17T09:32:42Z  ...  embarcar desembarcar cptm tenha cuidado altura...
# 8469  2017-02-17T08:39:25Z  ...  cptm linha esmeralda operacao normal linha tur...
#
# [8470 rows x 7 columns]

# %% [markdown]
# ## Nuvem de palavras

# %% [markdown]
# Fonte: https://amueller.github.io/word_cloud/index.html

# %%
# combinar as linhas em texto inteiro
texto_completo = " ".join(s for s in dados_cptm['texto_twitter_ajustado'])
texto_completo
# Out:
# 'esperando trem absurdo cptm linha coral velocidade reduzida linha safira velocidade reduzida transitosp cptm linha esmeralda operacao normal linha turquesa operacao normal transitosp cptm linha rubi velocidade reduzida linha diamante velocidade reduzida transitosp durante semana reprimem comercio irregular queria fizessem feriado cptm nota cptm linha coral velocidade reduzida linha safira velocidade reduzida transitosp cptm linha esmeralda operacao normal linha turquesa operacao normal transitosp cptm linha rubi velocidade reduzida linha diamante velocidade reduzida transitosp obras alteram circulacao trens durante carnaval infos cptm obras alteram circulacao trens durante carnaval infos cptm obras alteram circulacao trens durante carnaval infos cptm obras alteram circulacao trens durante carnaval infos cptm obras alteram circulacao trens durante carnaval infos cptm obras alteram circulacao trens durante carnaval infos cptm obras alteram circulacao trens durante carnaval infos cptm nota cptm apuracaosp desbloqueia hoje transporte bike liberado trens metro cptm bora pedalar bicicleta pedal bike trens linha rubi cptm voltam circular normalmente nota cptm apuracaosp nota cptm apuracaosp nota cptm apuracaosp nota cptm apuracaosp nota cptm apuracaosp acredito mozao aceitou paranapiacaba comigo expresso turistico cptm cptm linha coral velocidade reduzida linha safira velocidade reduzida transitosp cptm linha esmeralda operacao normal linha turquesa operacao normal transitosp cptm linha rubi velocidade reduzida linha diamante velocidade reduzida transitosp estacao autodromo cptm paulo ninguem cptm metro viaquatro muita gente bebendo nenhum seguranca ninguem cptm metro viaquatro muita gente bebendo nenhum seguranca feito coibir consumo bebida alcoolica trens estacoes carnaval segu tequila efeito festa augusta acorda horas guarda cptm cutuc cptm linha coral velocidade reduzida linha safira velocidade reduzida transitosp cptm linha esmeralda operacao normal linha turquesa operacao normal transitosp cptm linha rubi velocidade reduzida linha diamante velocidade reduzida transitosp estacao vila olimpia cptm paulo cptm nota tequila efeito festa augusta acorda horas guarda cptm cutucando bras cptm linha coral velocidade reduzida linha safira velocidade reduzida transitosp cptm linha esmeralda operacao normal linha turquesa operacao normal transitosp cptm linha rubi velocidade reduzida linha diamante velocidade reduzida transitosp cptm nota cptm nota terminal alvorada cicerorosalins estacao caieiras cptm cptm nota cptm nota cptm nota cptm linha coral velocidade reduzida linha safira velocidade reduzida transitosp cptm linha esmeralda operacao normal linha turquesa operacao normal transitosp cptm linha rubi velocidade reduzida linha diamante velocidade reduzida transitosp cptm nota cptm nota cptm nota cptm nota cptm nota cptm nota cptm nota cptm nota cptm nota cptm nota cptm nota cptm cptm linha coral velocidade reduzida linha safira velocidade reduzida transitosp cptm linha esmeralda operacao normal linha turquesa operacao normal transitosp cptm linha rubi velocidade reduzida linha diamante velocidade reduzida transitosp mandam trem quebra linha linha normal hoje cptm linha coral velocidade reduzida linha safira velocidade reduzida transitosp cptm linha esmeralda operacao normal linha turquesa operacao normal transitosp cptm linha rubi velocidade reduzida linha diamante velocidade reduzida transitosp sasa volta vamos passa catraca linha azul metro bilhete passa troco esqueci nome kkkkk enfim cptm cptm linha coral velocidade reduzida linha safira velocidade reduzida transitosp cptm linha esmeralda operacao normal linha turquesa operacao normal transitosp cptm linha rubi velocidade reduzida linha diamante velocidade reduzida transitosp estacao calmon viana cptm suzano sptv resolve materia reclamando cita psdb site cptm trens cptm linha coral velocidade reduzida linha safira velocidade reduzida transitosp cptm linha esmeralda operacao normal li ...

# %% [markdown]
# - Nuvem simples

# %%
wc = WordCloud()
#wc = WordCloud(max_font_size=40, background_color='white')
wc.generate(texto_completo)

# %%
plt.figure()
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
#plot_path = 'cptm_wordcloud.png'
#plt.savefig(plot_path,  bbox_inches='tight', dpi = 100)
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# - Nuvem com formato

# %%
trem_formato = np.array(Image.open('trem.png'))

# %%
plt.figure()
plt.imshow(trem_formato, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 715.5, 361.5, -0.5)

# %%
wc = WordCloud(background_color='white', mask=trem_formato)

# %%
wc.generate(texto_completo)

# %%
wc.to_file("trem.png")

# %%
plt.figure()
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plot_path = 'trem_cptm_wordcloud.png'
plt.savefig(plot_path,  bbox_inches='tight', dpi = 300)
